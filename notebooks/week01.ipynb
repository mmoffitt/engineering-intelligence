# %% [markdown]
# # Week #1: Welcome to Colab!
#
# The first few sections of this week's notebook come from Google's [official introductory guide](https://colab.research.google.com/notebooks/intro.ipynb). With each passing week, the contents of these notebooks will get more and more specific to the aims of the internship.

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).

# %% [markdown]
# ## Week 1 Practice: Python Basics
#
# In this section, you will complete a few beginner exercises designed to build confidence with core Python skills.
#
# For each exercise:
# 1. Write your code in the provided starter cell.
# 2. Click the **Check Exercise** button.
# 3. Read the feedback and revise if needed.
#
# Most programmers need multiple tries when learning a new concept. Iteration is normal and expected.

# %%
# Run this cell once before the exercises.
# It sets up simple "Check Exercise" buttons.

try:
    import ipywidgets as widgets
    from IPython.display import display
except Exception as exc:
    raise RuntimeError(
        "ipywidgets is required for check buttons in this notebook."
    ) from exc


def make_check_button(check_fn):
    button = widgets.Button(description="Check Exercise", button_style="info")
    output = widgets.Output()

    def on_click(_):
        output.clear_output()
        with output:
            check_fn()

    button.on_click(on_click)
    display(button, output)


print("Checker setup complete. You can now use the buttons below.")

# %% [markdown]
# ### Exercise 1: Variables and Arithmetic
#
# Create a variable named `seconds_in_hour` and set it equal to `60 * 60`.
#
# Then create `seconds_in_two_hours` and set it to `2 * seconds_in_hour`.
#
# Expected value for `seconds_in_two_hours`: **7200**.

# %%
# Write your solution here for Exercise 1
seconds_in_hour = None
seconds_in_two_hours = None

# %%
# Click to check Exercise 1

def check_exercise_1():
    if "seconds_in_hour" not in globals() or "seconds_in_two_hours" not in globals():
        print("Good start. Define both variables first, then try again.")
        return

    if seconds_in_hour != 3600:
        print("Close: `seconds_in_hour` should evaluate to 3600.")
        return

    if seconds_in_two_hours != 7200:
        print("Close: `seconds_in_two_hours` should evaluate to 7200.")
        return

    print("Great work. Exercise 1 is correct.")


make_check_button(check_exercise_1)

# %% [markdown]
# ### Exercise 2: Lists and Loops
#
# Create a list named `numbers` with values `[1, 2, 3, 4, 5]`.
#
# Use a `for` loop to compute the sum of all values into a variable named `total`.
#
# Expected value for `total`: **15**.

# %%
# Write your solution here for Exercise 2
numbers = []
total = None

# %%
# Click to check Exercise 2

def check_exercise_2():
    if "numbers" not in globals() or "total" not in globals():
        print("You are close. Define `numbers` and `total`, then re-check.")
        return

    if numbers != [1, 2, 3, 4, 5]:
        print("Check the list values: `numbers` should be [1, 2, 3, 4, 5].")
        return

    if total != 15:
        print("Close: `total` should evaluate to 15.")
        return

    print("Nice job. Exercise 2 is correct.")


make_check_button(check_exercise_2)

# %% [markdown]
# ### Exercise 3: Functions and Conditionals
#
# Write a function named `is_even(n)` that:
# - returns `True` when `n` is even
# - returns `False` when `n` is odd
#
# Use the modulo operator `%`.

# %%
# Write your solution here for Exercise 3
def is_even(n):
    # Replace this with your implementation
    return None

# %%
# Click to check Exercise 3

def check_exercise_3():
    if "is_even" not in globals():
        print("Good start. Define `is_even(n)` first, then run this check again.")
        return

    try:
        tests = [
            (2, True),
            (3, False),
            (0, True),
            (11, False),
        ]
        for n, expected in tests:
            got = is_even(n)
            if got is not expected:
                print(f"Close: `is_even({n})` returned {got}, expected {expected}.")
                return
    except Exception as exc:
        print("Your function raised an error. Read the message, adjust your code, and try again:", exc)
        return

    print("Excellent work. Exercise 3 is correct.")


make_check_button(check_exercise_3)

# %% [markdown]
# ## Nice progress
#
# If all three checks pass, you are in a strong position for Week 2.
#
# Optional stretch challenge:
# - Create a `3 x 3` grid (a list of lists)
# - Write a function that prints one row per line
#
# If you get stuck, write down what you tried and where it broke. That is real engineering practice.
